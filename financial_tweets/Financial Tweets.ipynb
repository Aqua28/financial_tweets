# %%
import pandas as pd
import numpy as np
import pandas as pd
data = pd.read_csv('financial-tweets/stockerbot-export.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-a0ca4075d7e7> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 data = pd.read_csv('financial-tweets/stockerbot-export.csv')
#
# ...

# %%
data
# Out:
#     ticker                                         name
# 0     NVAX                                      Novavax
# 1     SIRI                                    Sirius XM
# 2      QQQ                                  Invesco QQQ
# 3     AAPL                                        Apple
# 4     MSFT                                    Microsoft
# 5       FB                                     Facebook
# 6       MU                                       Micron
# 7     NVDA                                       NVIDIA
# 8     INTC                                        Intel
# 9      CSX                                          CSX
# 10    CSCO                                Cisco Systems
# 11    HBAN                        Huntington Bancshares
# 12     MAT                                       Mattel
# 13   CMCSA                                      Comcast
# 14    EBAY                                         eBay
# 15    JBLU                              JetBlue Airways
# ...
